# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

df = pd.read_csv('Part2.csv')
print(df)
result = df.to_numpy()
# Out:
#         time  distance  orientation
# 0   0.037153  2.219190    -2.121222
# 1   0.142732  2.220201    -2.070100
# 2   0.248122  2.224540    -1.909438
# 3   0.349092  2.230342    -1.739554
# 4   0.454896  2.236381    -1.543051
# ..       ...       ...          ...
# 60  6.448873  0.199290     0.073226
# 61  6.564312  0.166633     0.085603
# 62  6.673316  0.144497     0.096333
# 63  6.779553  0.118922     0.118580
# 64  6.890514  0.112500     0.121878
#
# [65 rows x 3 columns]

# %%
import numpy as np
# %matplotlib inline

ax = gca()
ax.set_aspect('equal', adjustable='box')
grid()
plot(result[:,0], result[:,1])
plt.axhline(y = 0, color = 'r', linestyle = '--')
plt.title("Dist to the Goal over Time")
show()

# %%
ax = gca()
ax.set_aspect('equal', adjustable='box')
grid()
plot(result[:,0], result[:,2])
plt.axhline(y = 0, color = 'r', linestyle = '--')
plt.title("Orientation Error over Time")
show()
